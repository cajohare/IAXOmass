# %%
from numpy import *
import matplotlib.pyplot as plt
dat = loadtxt('RGBcurve.txt')
g_ag = dat[:,1]*1e-10
g_ae = sqrt(dat[:,0]*4*pi*1e-26)
plt.plot(g_ae**2.0,g_ag,'-')
plt.plot(g_ae**2.0,(2.8e-12)**2.0/g_ae,'r-')
plt.show()
# Out:
# /Users/ciaranohare/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in divide
#   import sys
